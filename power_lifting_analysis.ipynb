# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../datasets/powerlifting_dataset.csv")
df
# Out:
#          Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)
# 0     Jessica Wilson   46        59 kg  Bench Press                 269
# 1           John Doe   60        83 kg  Bench Press                 179
# 2        Emily Davis   41       105 kg  Bench Press                 235
# 3        Emily Davis   33        66 kg        Squat                 359
# 4       Laura Taylor   56        74 kg     Deadlift                 221
# ...              ...  ...          ...          ...                 ...
# 2995        John Doe   46        74 kg  Bench Press                 246
# 2996      Daniel Lee   39         Open     Deadlift                 244
# 2997    Sarah Thomas   62         Open        Squat                 148
# 2998     Chris Brown   32        93 kg  Bench Press                 333
# 2999      Daniel Lee   22        83 kg     Deadlift                 280
#
# [3000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Lifter Name           0
# Age                   0
# Weight Class          0
# Lift Type             0
# Amount Lifted (kg)    0
# dtype: int64

# %%
df.dtypes
# Out:
# Lifter Name           object
# Age                    int64
# Weight Class          object
# Lift Type             object
# Amount Lifted (kg)     int64
# dtype: object

# %%
print("Basic statistics for Amount Lifted in Kg : ")
df['Amount Lifted (kg)'].describe()
# Out:
# Basic statistics for Amount Lifted in Kg :
# count    3000.000000
# mean      250.332667
# std        86.281208
# min       100.000000
# 25%       176.750000
# 50%       250.000000
# 75%       325.250000
# max       399.000000
# Name: Amount Lifted (kg), dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(30, 6))
plt.scatter(df['Age'], df['Amount Lifted (kg)'], color='blue', alpha=0.6)

# Adding title and labels
plt.title('Scatter Plot of Amount Lifted vs. Age')
plt.xlabel('Age')
plt.ylabel('Amount Lifted (kg)')

# Display the plot
plt.show()

# %%
df['Age Group'] = pd.cut(df['Age'], bins=[0, 20, 30, 40, 50, 60, 70], labels=['<20', '20-29', '30-39', '40-49', '50-59', '60+'])

# Plot boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Age Group', y='Amount Lifted (kg)', data=df)

# Adding title and labels
plt.title('Box Plot of Amount Lifted by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Amount Lifted (kg)')

plt.show()

# %%
top_10_strong = df.sort_values(by='Amount Lifted (kg)', ascending=False).head(10)
top_10_strong
# Out:
#            Lifter Name  Age Weight Class    Lift Type  Amount Lifted (kg)  \
# 2778  Matthew Anderson   29        66 kg  Bench Press                 399
# 2758       Emily Davis   40        83 kg        Squat                 399
# 2795        Jane Smith   34        52 kg     Deadlift                 399
# 1207   Michael Johnson   51        93 kg  Bench Press                 399
# 2105   Michael Johnson   57        93 kg        Squat                 399
# 2742       Chris Brown   39       120 kg     Deadlift                 399
# 1409        Daniel Lee   24        66 kg        Squat                 399
# 1727      Sarah Thomas   51        59 kg     Deadlift                 399
# 2976       Emily Davis   48         Open  Bench Press                 399
# 585         Jane Smith   58        74 kg     Deadlift                 399
#
#      Age Group
# 2778     20-29
# 2758     30-39
# 2795     30-39
# 1207     50-59
# 2105     50-59
# 2742     30-39
# 1409     20-29
# 1727     50-59
# ...

# %%
df['Lift Type'].unique()
# Out:
# array(['Bench Press', 'Squat', 'Deadlift'], dtype=object)

# %%
bench_press_top5 = df[df['Lift Type'] == 'Bench Press'].sort_values(by='Amount Lifted (kg)', ascending=False).head(5)[['Lifter Name', 'Age', 'Weight Class', 'Amount Lifted (kg)']]

# Filter and sort for Squat
squat_top5 = df[df['Lift Type'] == 'Squat'].sort_values(by='Amount Lifted (kg)', ascending=False).head(5)[['Lifter Name', 'Age', 'Weight Class', 'Amount Lifted (kg)']]

# Filter and sort for Deadlift
deadlift_top5 = df[df['Lift Type'] == 'Deadlift'].sort_values(by='Amount Lifted (kg)', ascending=False).head(5)[['Lifter Name', 'Age', 'Weight Class', 'Amount Lifted (kg)']]

# Display the tables
print("Top 5 Bench Press Lifters:")
print(bench_press_top5)
print()
print("Top 5 squats Lifters:")
print(squat_top5)
print()
print("Top 5 deadlift Lifters:")
print(deadlift_top5)
# Out:
# Top 5 Bench Press Lifters:
#            Lifter Name  Age Weight Class  Amount Lifted (kg)
# 2778  Matthew Anderson   29        66 kg                 399
# 1207   Michael Johnson   51        93 kg                 399
# 2976       Emily Davis   48         Open                 399
# 2140        Jane Smith   57        74 kg                 399
# 696       Sarah Thomas   63        59 kg                 398
#
# Top 5 squats Lifters:
#           Lifter Name  Age Weight Class  Amount Lifted (kg)
# 1409       Daniel Lee   24        66 kg                 399
# 2130       Jane Smith   28        93 kg                 399
# 2758      Emily Davis   40        83 kg                 399
# 2699      Emily Davis   53        74 kg                 399
# 2105  Michael Johnson   57        93 kg                 399
#
# Top 5 deadlift Lifters:
#        Lifter Name  Age Weight Class  Amount Lifted (kg)
# 585     Jane Smith   58        74 kg                 399
# ...

# %%
# Plotting the scatter plot
plt.figure(figsize=(12, 8))

# Scatter plot for Bench Press
plt.scatter(bench_press_top5['Weight Class'], bench_press_top5['Age'], color='red', s=100, label='Bench Press')

# Scatter plot for Squat
plt.scatter(squat_top5['Weight Class'], squat_top5['Age'], color='blue', s=100, label='Squat')

# Scatter plot for Deadlift
plt.scatter(deadlift_top5['Weight Class'], deadlift_top5['Age'], color='green', s=100, label='Deadlift')

# Adding labels and title
plt.xlabel('Weight Class')
plt.ylabel('Age')
plt.title('Top 5 Lifters by Lift Type to lift 398-399kgs')
plt.legend()

# Display the plot
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Age'], bins=20, kde=True, color='salmon')
plt.title('Age Distribution of Lifters')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
x=df['Lift Type']
y=df['Amount Lifted (kg)']
sns.barplot(x,y, estimator=np.mean, palette='viridis')

# Add a title, labels, and grid to the chart
plt.title('Average Amount Lifted by Lift Type')
plt.xlabel('Lift Type')
plt.ylabel('Average Amount Lifted (kg)')
plt.grid(True)

# Show the chart
plt.show()
# Out:
# c:\Users\yuvraj\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Weight Class', data=df)
plt.title('Weight Class Distribution')
plt.show()

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x='Weight Class', y='Amount Lifted (kg)', hue='Lift Type', data=df)
plt.title('Box plot of Amount Lifted (kg) by Weight Class and Lift Type')
plt.show()
